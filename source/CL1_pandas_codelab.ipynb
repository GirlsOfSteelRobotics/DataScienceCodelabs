# %%
"""
This cell imports all the necessary 3rd party libraries and loads our scouted matches
"""

import pandas as pd
pd.set_option('display.max_columns', None)

scouted_data = df = pd.read_csv("data/scouted_data.csv")

# %%
"""
Step 1.

"print" the scouted data dataframe. You can either explicitly print() it, or just have it be the last item in the cell
"""

scouted_data
# Out:
#      org_key  year event_key      match_key  match_number  \
# 0    frc4467  2025  2025tnkn   2025tnkn_qm1             1
# 1    frc4467  2025  2025tnkn   2025tnkn_qm1             1
# 2    frc4467  2025  2025tnkn   2025tnkn_qm1             1
# 3    frc4467  2025  2025tnkn   2025tnkn_qm1             1
# 4    frc4467  2025  2025tnkn   2025tnkn_qm1             1
# ..       ...   ...       ...            ...           ...
# 466  frc4467  2025  2025tnkn  2025tnkn_qm79            79
# 467  frc4467  2025  2025tnkn  2025tnkn_qm79            79
# 468  frc4467  2025  2025tnkn  2025tnkn_qm79            79
# 469  frc4467  2025  2025tnkn  2025tnkn_qm79            79
# 470  frc4467  2025  2025tnkn  2025tnkn_qm79            79
#
#                      time alliance team_key  totalAutoPoints  \
# 0    4/4/2025 12:50:00 PM     blue    frc21               10
# 1    4/4/2025 12:50:00 PM     blue  frc3824                6
# 2    4/4/2025 12:50:00 PM      red  frc5045                0
# ...

# %%
"""
Step 2a. Display all the data for a single column "totalTeleopPoints"
"""

scouted_data[["team_key", "totalTeleopPoints"]]
# Out:
#     team_key  totalTeleopPoints
# 0      frc21                 29
# 1    frc3824                 18
# 2    frc5045                  4
# 3    frc1466                 26
# 4    frc4630                  8
# ..       ...                ...
# 466  frc3324                 42
# 467  frc3139                 20
# 468  frc3843                 20
# 469  frc5002                 12
# 470  frc7072                 30
#
# [471 rows x 2 columns]

# %%
"""
Step 2b. Display all the data for a multiple columns: "team_key", "totalTeleopPoints", "totalAUtoPoints"
"""
scouted_data[["team_key", "totalTeleopPoints"]]
# Out:
#     team_key  totalTeleopPoints
# 0      frc21                 29
# 1    frc3824                 18
# 2    frc5045                  4
# 3    frc1466                 26
# 4    frc4630                  8
# ..       ...                ...
# 466  frc3324                 42
# 467  frc3139                 20
# 468  frc3843                 20
# 469  frc5002                 12
# 470  frc7072                 30
#
# [471 rows x 2 columns]

# %%
"""
Step 3a. Query for all the matches where team "frc3504" played
"""
# Out:
# '\nStep 3a. Query for all the matches where team "frc3504" played\n'

# %%
"""
Step 3b. Query for all the matches where team a team died during a match
"""

scouted_data[scouted_data["diedDuringMatch"] != 0]
# Out:
#      org_key  year event_key      match_key  match_number  \
# 7    frc4467  2025  2025tnkn   2025tnkn_qm2             2
# 18   frc4467  2025  2025tnkn   2025tnkn_qm4             4
# 23   frc4467  2025  2025tnkn   2025tnkn_qm4             4
# 34   frc4467  2025  2025tnkn   2025tnkn_qm6             6
# 38   frc4467  2025  2025tnkn   2025tnkn_qm7             7
# 45   frc4467  2025  2025tnkn   2025tnkn_qm8             8
# 54   frc4467  2025  2025tnkn  2025tnkn_qm10            10
# 69   frc4467  2025  2025tnkn  2025tnkn_qm12            12
# 70   frc4467  2025  2025tnkn  2025tnkn_qm12            12
# 98   frc4467  2025  2025tnkn  2025tnkn_qm17            17
# 99   frc4467  2025  2025tnkn  2025tnkn_qm17            17
# 134  frc4467  2025  2025tnkn  2025tnkn_qm23            23
# 144  frc4467  2025  2025tnkn  2025tnkn_qm25            25
# 152  frc4467  2025  2025tnkn  2025tnkn_qm26            26
# 236  frc4467  2025  2025tnkn  2025tnkn_qm40            40
# ...

# %%
"""
Step 3b. Query for all the instances when a team scored more than 8 pieces of coral
"""
# Out:
# '\nStep 3b. Query for all the instances when a team scored more than 8 pieces of coral\n'

# %%
"""
Step XXXX. Calculate the averages stats per team and display them
"""
# Out:
# '\nStep XXXX. Calculate the averages stats per team and display them\n'

# %%
"""
Step XXXX. Filter teams that scored an average of more than 2 pieces of algae
"""
# Out:
# '\nStep XXXX. Filter teams that scored an average of more than 2 pieces of algae\n'

# %%
"""
Step XXXX. Query for ALL the scouted data for the teams listed in the array
"""

teams_in_match = ["frc21", "frc3824", "frc5045", "frc1466", "frc4630", "frc5744"]

# %%
"""
Step XXXX. Query for the average scouted data for the teams listed in the array
"""

teams_in_match = ["frc21", "frc3824", "frc5045", "frc1466", "frc4630", "frc5744"]

# %%
df = pd.DataFrame({
    'Name': ['Alice', 'Bob', 'Sam', 'Charlie', 'Tom', 'Bob'],
    'Age': [25, 30, 35, 30, 42, 21],
    'City': ['New York', 'London', 'Paris', 'Pittsburgh', "Rochester", "Seattle"]
})
df

# df["Favorite Color"] = ["Red", "Green", "Blue", "Pink", "Yellow", "Orange"]

# # Or using existing data
# df["Dog Years"] = df["Age"] / 7.0

# df.sum()

df.groupby("Name").median(numeric_only=True)
# Out:
#           Age
# Name
# Alice    25.0
# Bob      25.5
# Charlie  30.0
# Sam      35.0
# Tom      42.0
